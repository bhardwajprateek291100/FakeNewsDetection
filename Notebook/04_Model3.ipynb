# %% [markdown]
# ##**Mounting Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**Import Packages**

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import  RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %% [markdown]
# ##**Loading Dataset**

# %%
train_data = pd.read_csv("/content/drive/MyDrive/BTP/Files/train_data.csv", encoding='utf-8')
test_data = pd.read_csv("/content/drive/MyDrive/BTP/Files/test_data.csv", encoding='utf-8')

# %%
Y_train = train_data['label'].values
Y_test = test_data['label'].values

# %%
X_train = train_data.drop(['label','statement'], axis = 1).values
X_test = test_data.drop(['label','statement'], axis = 1).values

# %%
X_train.shape
# Out:
# (48379, 85)

# %% [markdown]
# ##**Models**

# %% [markdown]
# Logistic Regession

# %%
lr = LogisticRegression()
lr.fit(X_train, Y_train)

print("Training Accuracy: ", lr.score(X_train, Y_train))
print("Testing AccuracY: ", lr.score(X_test, Y_test))
# Out:
# Training Accuracy:  0.7779408421009115
# Testing AccuracY:  0.7804592213203698
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %% [markdown]
# Naive Bayes

# %%
nb = GaussianNB()
nb.fit(X_train, Y_train)

print("Training Accuracy: ", nb.score(X_train, Y_train))
print("Testing AccuracY: ", nb.score(X_test, Y_test))
# Out:
# Training Accuracy:  0.5568738502242708
# Testing AccuracY:  0.5569252137679587

# %% [markdown]
# SVM

# %%
svm = SVC()
svm.fit(X_train, Y_train)

print("Training Accuracy: ", svm.score(X_train, Y_train))
print("Testing AccuracY: ", svm.score(X_test, Y_test))
# Out:
# Training Accuracy:  0.7748816635316976
# Testing AccuracY:  0.7699118885368289

# %% [markdown]
# Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(X_train, Y_train)

print("Training Accuracy: ", rf.score(X_train, Y_train))
print("Testing AccuracY: ", rf.score(X_test, Y_test))
# Out:
# Training Accuracy:  0.999751958494388
# Testing AccuracY:  0.7966491601197969

# %% [markdown]
# Gradient Boosting

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train, Y_train)

print("Training Accuracy: ", gb.score(X_train, Y_train))
print("Testing AccuracY: ", gb.score(X_test, Y_test))
# Out:
# Training Accuracy:  0.7861882221625085
# Testing AccuracY:  0.7727765962064326

# %% [markdown]
# XGBoost Classifier

# %%
xgb = XGBClassifier()
xgb.fit(X_train, Y_train)

print("Training Accuracy: ", xgb.score(X_train, Y_train))
print("Testing AccuracY: ", xgb.score(X_test, Y_test))
# Out:
# Training Accuracy:  0.7834804357262448
# Testing AccuracY:  0.7707799817700421

# %% [markdown]
# Bagging With Decision Tree

# %%
bag_dt = BaggingClassifier(
    base_estimator = DecisionTreeClassifier()
)
bag_dt.fit(X_train, Y_train)

print("Training Accuracy: ", bag_dt.score(X_train, Y_train))
print("Testing AccuracY: ", bag_dt.score(X_test, Y_test))
# Out:
# Training Accuracy:  0.9912565369271792
# Testing AccuracY:  0.7698684838751682
